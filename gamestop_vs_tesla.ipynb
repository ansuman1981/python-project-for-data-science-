# %% [markdown]
# <a href="https://colab.research.google.com/github/ansuman1981/python-project-for-data-science-/blob/main/gamestop_vs_tesla.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Tesla vs GameStop stock**

# %% [markdown]
# **section 1**
#
# **Extract Tesla stock data**
#
# in this first section we are using the first workflow which is extract data.
#
# **1. Extract data**
# in extract data we collect the data:
#
#
# *   stock prices
# *   revenue/profit data
#
# we will use:
#
#
# *   APIs(yfinance)
# *   webscracping
# *   pandas

# %%
# install yfinance
# !pip install yfinance

# %%
# import libraries
import yfinance as yf
import pandas as pd

# %%
# Create tesla stock object
tesla = yf.Ticker("TSLA")

# %%
# Extract Historical Stock Data
tesla_data = tesla.history(period="max") # Get all available Tesla stock history

# %% [markdown]
# **Reset Index**
# what the reson behid we are reseting the index:
#
# intitally the date is stored as the index.we convert it to a nominal column for easier analysis and plotting.

# %%
# Reset index
tesla_data.reset_index(inplace=True)

# %%
# view the data
tesla_data.head()
# Out:
#                        Date      Open      High       Low     Close  \
# 0 2010-06-29 00:00:00-04:00  1.266667  1.666667  1.169333  1.592667
# 1 2010-06-30 00:00:00-04:00  1.719333  2.028000  1.553333  1.588667
# 2 2010-07-01 00:00:00-04:00  1.666667  1.728000  1.351333  1.464000
# 3 2010-07-02 00:00:00-04:00  1.533333  1.540000  1.247333  1.280000
# 4 2010-07-06 00:00:00-04:00  1.333333  1.333333  1.055333  1.074000
#
#       Volume  Dividends  Stock Splits
# 0  281494500        0.0           0.0
# 1  257806500        0.0           0.0
# 2  123282000        0.0           0.0
# 3   77097000        0.0           0.0
# 4  103003500        0.0           0.0

# %% [markdown]
# ## Tesla stock data was successfully extracted using the yfinance library. The dataset includes historical stock prices and trading volume information.
# information we get from the data:
#
# *  Date
# *  Open
# *  High
# *  Low
# *  Close
# *  Volume
# *  Dividends
# *  Stock Splits

# %%
tesla_data.tail() # view the last row
# it shows latests stock data and newest date
# Out:
#                           Date        Open        High         Low  \
# 3988 2026-05-07 00:00:00-04:00  407.480011  415.829987  402.119995
# 3989 2026-05-08 00:00:00-04:00  416.480011  431.200012  416.390015
# 3990 2026-05-11 00:00:00-04:00  422.160004  449.160004  416.799988
# 3991 2026-05-12 00:00:00-04:00  441.410004  447.799988  422.260010
# 3992 2026-05-13 00:00:00-04:00  436.670013  453.399994  430.209991
#
#            Close    Volume  Dividends  Stock Splits
# 3988  411.790009  64294200        0.0           0.0
# 3989  428.350006  65050000        0.0           0.0
# 3990  445.000000  78376100        0.0           0.0
# 3991  433.450012  60569300        0.0           0.0
# 3992  445.269989  67999700        0.0           0.0

# %%
# check dataset shape
tesla_data.shape # row and column
# Out:
# (3993, 8)

# %%
# see clomm name
""" check data informations """
tesla_data.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividends',
#        'Stock Splits'],
#       dtype='object')

# %%
# basic data info
tesla_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3993 entries, 0 to 3992
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          3993 non-null   datetime64[ns, America/New_York]
#  1   Open          3993 non-null   float64
#  2   High          3993 non-null   float64
#  3   Low           3993 non-null   float64
#  4   Close         3993 non-null   float64
#  5   Volume        3993 non-null   int64
#  6   Dividends     3993 non-null   float64
#  7   Stock Splits  3993 non-null   float64
# dtypes: datetime64[ns, America/New_York](1), float64(6), int64(1)
# memory usage: 249.7 KB

# %%
# basic statastics
tesla_data.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  3993.000000  3993.000000  3993.000000  3993.000000  3.993000e+03
# mean    106.110588   108.396200   103.692567   106.095002  9.597289e+07
# std     132.038212   134.819454   129.050535   131.977589  7.502907e+07
# min       1.076000     1.108667     0.998667     1.053333  1.777500e+06
# 25%      12.956000    13.232667    12.720667    12.982000  5.171100e+07
# 50%      20.330000    20.626667    19.943333    20.373333  8.187380e+07
# 75%     217.800003   222.050003   212.360001   217.610001  1.199515e+08
# max     489.880005   498.829987   485.329987   489.880005  9.140820e+08
#
#        Dividends  Stock Splits
# count     3993.0   3993.000000
# mean         0.0      0.002004
# std          0.0      0.092266
# min          0.0      0.000000
# 25%          0.0      0.000000
# 50%          0.0      0.000000
# 75%          0.0      0.000000
# max          0.0      5.000000

# %% [markdown]
# # EDA
# **Exploratory Data Analysis (EDA)**
#
# **why EDA matters**
# * what data is exists
# * whether data is clean
# * what trend may appear
#
# The Tesla stock dataset was inspected using exploratory data analysis techniques such as viewing rows, checking column types, and analyzing statistical summaries.

# %% [markdown]
# # **Extract Revenue data through Web Scraping**
# now we move to the second most major part of the project:
#
# **Extracting company revenue/profit data from webpages.**
#
# ## What is Revenue data?
# the money earned by the business company  from its business operations.
#
# ## Why compare Revenue with stock data?
# Because sometimes:
# * stoc price rises but comapany profit and loss and revenus do not.
#
# **This helps Analysts understand:**
# * hype
# * overvaluation
# * investor behavior

# %%
# create revenue dataset
tesla_revenue = pd.DataFrame({
    "Date": ["2024", "2023", "2022", "2021", "2020"],
    "Revenue": ["96,773", "81,462", "53,823", "31,536", "21,461"]
})

# %%
# view the dataset
tesla_revenue.head()
# Out:
#    Date Revenue
# 0  2024  96,773
# 1  2023  81,462
# 2  2022  53,823
# 3  2021  31,536
# 4  2020  21,461

# %%
# check dataset info
""" check data types and missing values """
tesla_revenue.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     5 non-null      object
#  1   Revenue  5 non-null      object
# dtypes: object(2)
# memory usage: 212.0+ bytes

# %%
# clean revenue column
tesla_revenue["Revenue"] = tesla_revenue["Revenue"].str.replace(",","")

# %%
# convert Revenue to numeric
tesla_revenue["Revenue"] = tesla_revenue["Revenue"].astype(int)

# %%
# verify the info
tesla_revenue.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     5 non-null      object
#  1   Revenue  5 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 212.0+ bytes

# %%
# statistical informations
tesla_revenue.describe()
# Out:
#             Revenue
# count      5.000000
# mean   57011.000000
# std    32022.685373
# min    21461.000000
# 25%    31536.000000
# 50%    53823.000000
# 75%    81462.000000
# max    96773.000000

# %% [markdown]
# ## What we did in this phase:
#
# | Skill               | Purpose               |
# | ------------------- | --------------------- |
# | DataFrames          | structured data       |
# | Data cleaning       | remove commas         |
# | Type conversion     | string → numeric      |
# | EDA                 | dataset understanding |
# | Financial data prep | analytics workflow    |

# %% [markdown]
# # Exploratory Data Analysis & Visualization
# **now we are moving do the third phase of the project**
#
# where the projects start becoming visually analytical with:
#
#
# *   charts
# *   trends anyalysis
# * stock vs revenue comparision
# * generate insights
#
# **Goal of this phase**
# transform raw financial data into:
#
# * visual understanding
# * business insights
# * trends/partten

# %%
# import visualization library
import matplotlib.pyplot as plt

# %% [markdown]
# ## what is matpllotlib ?
# matplotlib is a python visualization library used for:
# * graphs
# * charts
# * plots

# %%
# visualize Tesla Revenue
plt.figure(figsize=(10,5)) # create graphs size
plt.plot(tesla_revenue["Date"], tesla_revenue["Revenue"])
plt.title("Tesla Revenue Growth")
plt.xlabel("Year")
plt.ylabel("Revenue")
plt.show()

# %% [markdown]
# ## Result
# we can see in the plot graph properly the year and the revenu for the Tesla company. It shows the Tesla Revenue Growth plot where we can see every year tesla revenue has riesed to a new hight specsily after 2022.

# %%
#  visulize Tesla Stock Price
plt.figure(figsize=(12,5))

plt.plot(tesla_data["Date"], tesla_data["Close"])

plt.title("Tesla Stock Price Trend")

plt.xlabel("Date")

plt.ylabel("Closing Price")

plt.show()

# %% [markdown]
# ## Resul
# This is a historical Tesla Stock market movement. Its shows the behavior of the investor and market. This plot shows date and closing price of the Tesla Stock.
#
#
# ## Now we have two visulization
# | Graph         | Meaning                  |
# | ------------- | ------------------------ |
# | Revenue graph | business growth          |
# | Stock graph   | investor/market behavior |

# %% [markdown]
# # Website
#
# #   ↓
#
# # Download HTML
#
# #   ↓
#
# # Parse HTML
#
# #   ↓
#
# # Find revenue table
#
# #   ↓
#
# # Convert into DataFrame

# %%
# import libraries
import requests
from bs4 import BeautifulSoup
import pandas as pd
from io import StringIO

# %%
# download webpage
url = "https://books.toscrape.com/"

# %%
response = requests.get(url)

# %%
html_data = response.text

# %%
soup = BeautifulSoup(html_data, "html.parser")

# %%
print(soup.title)
# Out:
# <title>
#     All products | Books to Scrape - Sandbox
# </title>

# %% [markdown]
# ## Important
# we are using **Macrotrends** use commanly used to get real bases data or info about revenue and other comapnies info and the main reasons are:
# * esier to scrape
# * conatains revenue tables
# * less blocking then yahoo

# %%
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/124.0.0.0 Safari/537.36",
    "Accept-Language": "en-US,en;q=0.9",
    "Accept-Encoding": "gzip, deflate, br",
    "Referer": "https://www.google.com/",
    "DNT": "1",
    "Connection": "keep-alive",
    "Upgrade-Insecure-Requests": "1"
}

# %%
# request Webpage
html_data =  requests.get(url,headers=headers).text

# %% [markdown]
# ## What happen here?
# **visit webpage --- download HTML source code**

# %%
soup = BeautifulSoup(html_data, "html.parser")
